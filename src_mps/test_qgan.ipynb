# %%
from tools.training_init import run_single_training

run_single_training()
# Out:
# CPU device selected.
# c:\Users\f52ga\miniforge3\envs\qgan\Lib\site-packages\pennylane\__init__.py:196: RuntimeWarning: PennyLane is not yet compatible with JAX versions > 0.6.2. You have version 0.7.0 installed. Please downgrade JAX to 0.6.2 to avoid runtime errors using python -m pip install jax~=0.6.0 jaxlib~=0.6.0
#   warnings.warn(
# Running in SINGLE RUN mode.
#
#
# ...
# run_timestamp: 2025-08-01__08-27-28,
# ----------------------------------------------
# load_timestamp: None,
# type_of_warm_start: none,
# warm_start_strength: 0.1,
# ----------------------------------------------
# system_size: 3,
# extra_ancilla: False,
# ancilla_mode: pass,
# ancilla_project_norm: re-norm,
# ancilla_topology: bridge,
# ancilla_connect_to: None,
# do_ancilla_1q_gates: True,
# start_ancilla_gates_randomly: True,
# ----------------------------------------------
# gen_layers: 3,
# gen_ansatz: ZZ_X_Z,
# ----------------------------------------------
# target_hamiltonian: custom_h,
# ...

# %%
from tools.training_init import run_single_training

run_single_training()
# Out:
# Running in SINGLE RUN mode.
#
#
# ...
# run_timestamp: 2025-07-31__13-11-26,
# ----------------------------------------------
# load_timestamp: None,
# type_of_warm_start: none,
# warm_start_strength: 0.1,
# ----------------------------------------------
# system_size: 3,
# extra_ancilla: False,
# ancilla_mode: pass,
# ancilla_project_norm: re-norm,
# ancilla_topology: bridge,
# ancilla_connect_to: None,
# do_ancilla_1q_gates: True,
# start_ancilla_gates_randomly: True,
# ----------------------------------------------
# gen_layers: 3,
# gen_ansatz: ZZ_X_Z,
# ----------------------------------------------
# target_hamiltonian: custom_h,
# custom_hamiltonian_terms: ['ZZZ'],
# custom_hamiltonian_strengths: [1.0],
# ----------------------------------------------
# epochs: 10,
# iterations_epoch: 300,
# log_every_x_iter: 10,
# save_fid_and_loss_every_x_iter: 1,
# max_fidelity: 0.99,
# steps_gen: 1,
# steps_dis: 1,
# ----------------------------------------------
# l_rate: 0.01,
# ...

# %%
import numpy as np
from scipy.linalg import expm
from numpy.testing import assert_allclose

# Pauli matrices
I = np.eye(2, dtype=complex)
X = np.array([[0, 1], [1, 0]], dtype=complex)
Y = np.array([[0, -1j], [1j, 0]], dtype=complex)
Z = np.array([[1, 0], [0, -1]], dtype=complex)
paulis = [I, X, Y, Z]

# Random real coefficients for A and B
np.random.seed(42)
alpha = np.random.uniform(-1, 1, size=4)
beta = np.random.uniform(-1, 1, size=4)

# Build A and B as linear combinations of Pauli matrices
A = sum(a * P for a, P in zip(alpha, paulis))
B = sum(b * P for b, P in zip(beta, paulis))

# Build lifted operators: A ⊗ I and I ⊗ B
A_lifted = np.kron(A, I)
B_lifted = np.kron(I, B)

# Total Hamiltonian
H = A_lifted + B_lifted

# Compute exponential of the sum
exp_H = expm(H)

# Compute separate exponentials
exp_A = expm(A)
exp_B = expm(B)

# Compute Kronecker product of exponentials
exp_kron = np.kron(exp_A, exp_B)

# Compare
assert_allclose(exp_H, exp_kron, rtol=1e-10, atol=1e-12)
print("✅ Test passed: exp(A⊗I + I⊗B) == exp(A)⊗exp(B)")
# Out:
# ✅ Test passed: exp(A⊗I + I⊗B) == exp(A)⊗exp(B)
